# %%
import numpy as np
import pandas as pd
import gensim
import nltk
import re
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

data = pd.read_csv('nmf_result.csv')
data.head()
# Out:
#    Unnamed: 0                                      original_text  \
# 0           0  From: lerxst@wam.umd.edu (where's my thing)\nS...
# 1           1  From: guykuo@carson.u.washington.edu (Guy Kuo)...
# 2           2  From: twillis@ec.ecn.purdue.edu (Thomas E Will...
# 3           3  From: jgreen@amber (Joe Green)\nSubject: Re: W...
# 4           4  From: jcm@head-cfa.harvard.edu (Jonathan McDow...
#
#                                       processed_text nmf_topic  topic_score
# 0  thing car nntp_poste host rac_wam park line wo...         6     0.150893
# 1  final call summary final call si clock report ...         9     0.022004
# 2  question organization purdue_university engine...         9     0.030069
# 3  division line distribution_world nntp_poste ho...         9     0.032953
# 4  question organization smithsonian_astrophysica...         9     0.016379

# %%
def cleanText(text):
    cleaned = re.sub("[^a-zA-Z0-9']"," ",text)
    return cleaned.strip()

# %%
x,y = np.asarray(data["processed_text"]),np.asarray(data["nmf_topic"])

x_cleaned = [cleanText(t) for t in x]
x_cleaned[:4]
# Out:
# ['thing car nntp poste host rac wam park line wonder enlighten car see day door sport car look late early call door really small addition front bumper separate rest body know tellme model name engine spec year production car make history info funky look car mail thank bring neighborhood lerxst',
#  'final call summary final call si clock report keyword si acceleration clock upgrade article line nntp poste host fair number brave soul upgrade si clock oscillator share experience poll send brief message detail experience procedure top speed attain cpu rate speed add card adapter heat sink hour usage day floppy disk functionality floppy especially request summarize next day add network knowledge base do clock upgrade answer poll thank',
#  'question organization purdue university engineering computer network line well folk finally give ghost weekend start life way back sooo m market new machine bit soon intend m look pick powerbook maybe bunch question hopefully answer know dirt next round powerbook introduction expect d hear suppose make appearence summer hear anymore access macleak wonder info hear rumor price drop powerbook line one duo go recently s impression display probably swing get disk rather really feel much well display yea look great store really good solicit opinion people day day worth take disk size money hit get active display realize real subjective question ve play machine computer store breifly figured opinion actually use machine daily prove helpful well hellcat perform thank bunch advance info email ill post summary news read time premium final corner conviction dangerous enemie truth lie nietzsche',
#  'division line distribution world nntp poste host amber write write article know chip far low level stuff go look pretty nice get quadrilateral fill command require point weitek address phone number i get information chip computer division thing really scare person sense winter']

# %%
x_tokenized = [[w for w in sentence.split(" ") if w != ""] for sentence in x_cleaned]
x_tokenized[0]
# Out:
# ['thing',
#  'car',
#  'nntp',
#  'poste',
#  'host',
#  'rac',
#  'wam',
#  'park',
#  'line',
#  'wonder',
#  'enlighten',
#  'car',
#  'see',
#  'day',
#  'door',
#  'sport',
#  'car',
#  'look',
#  'late',
#  'early',
#  'call',
#  'door',
#  'really',
#  'small',
#  'addition',
#  'front',
#  'bumper',
#  'separate',
#  'rest',
#  'body',
#  'know',
#  'tellme',
#  'model',
#  'name',
#  'engine',
#  'spec',
#  'year',
#  'production',
#  'car',
#  'make',
#  'history',
#  'info',
#  'funky',
#  'look',
#  'car',
#  'mail',
#  'thank',
#  'bring',
#  'neighborhood',
#  'lerxst']

# %%
# Now we'll create our model 
import time

start = time.time()

model = gensim.models.Word2Vec(x_tokenized,
                 size=100
                 # Size is the length of our vector.
                )

end = round(time.time()-start,2)
print("This process took",end,"seconds.")
# Out:
# This process took 6.28 seconds.

# %%
model.wv.most_similar("free")
# Out:
# [('customer', 0.7393264770507812),
#  ('business', 0.7295130491256714),
#  ('interest', 0.7236589193344116),
#  ('assistance', 0.7202563285827637),
#  ('fee', 0.7131897211074829),
#  ('consult', 0.6915130615234375),
#  ('service', 0.6912041306495667),
#  ('local', 0.6906707882881165),
#  ('directly', 0.6878638863563538),
#  ('maintain', 0.6841388940811157)]

# %% [markdown]
# ## Writing A Class To Create Sequences

# %%
class Sequencer():
    
    def __init__(self,
                 all_words,
                 max_words,
                 seq_len,
                 embedding_matrix
                ):
        
        self.seq_len = seq_len
        self.embed_matrix = embedding_matrix
        """
        temp_vocab = Vocab which has all the unique words
        self.vocab = Our last vocab which has only most used N words.
    
        """
        temp_vocab = list(set(all_words))
        self.vocab = []
        self.word_cnts = {}
        """
        Now we'll create a hash map (dict) which includes words and their occurencies
        """
        for word in temp_vocab:
            # 0 does not have a meaning, you can add the word to the list
            # or something different.
            count = len([0 for w in all_words if w == word])
            self.word_cnts[word] = count
            counts = list(self.word_cnts.values())
            indexes = list(range(len(counts)))
        
        # Now we'll sort counts and while sorting them also will sort indexes.
        # We'll use those indexes to find most used N word.
        cnt = 0
        while cnt + 1 != len(counts):
            cnt = 0
            for i in range(len(counts)-1):
                if counts[i] < counts[i+1]:
                    counts[i+1],counts[i] = counts[i],counts[i+1]
                    indexes[i],indexes[i+1] = indexes[i+1],indexes[i]
                else:
                    cnt += 1
        
        for ind in indexes[:max_words]:
            self.vocab.append(temp_vocab[ind])
                    
    def textToVector(self,text):
        # First we need to split the text into its tokens and learn the length
        # If length is shorter than the max len we'll add some spaces (100D vectors which has only zero values)
        # If it's longer than the max len we'll trim from the end.
        tokens = text.split()
        len_v = len(tokens)-1 if len(tokens) < self.seq_len else self.seq_len-1
        vec = []
        for tok in tokens[:len_v]:
            try:
                vec.append(self.embed_matrix[tok])
            except Exception as E:
                pass
        
        last_pieces = self.seq_len - len(vec)
        for i in range(last_pieces):
            vec.append(np.zeros(100,))
        
        return np.asarray(vec).flatten()

# %%
sequencer = Sequencer(all_words = [token for seq in x_tokenized for token in seq],
              max_words = 1200,
              seq_len = 15,
              embedding_matrix = model.wv
             )

# %%
test_vec = sequencer.textToVector("i am in love with you")
test_vec
# Out:
# array([ 0.38648486, -1.66779959, -0.55719811, ...,  0.        ,
#         0.        ,  0.        ])

# %%
test_vec.shape
# Out:
# (1500,)

# %% [markdown]
# ## PCA (Principal Component Analysis)

# %%
x_vecs = np.asarray([sequencer.textToVector(" ".join(seq)) for seq in x_tokenized])
print(x_vecs.shape)
# Out:
# (11314, 1500)

# %%
from sklearn.decomposition import PCA
pca_model = PCA(n_components=50)
pca_model.fit(x_vecs)
print("Sum of variance ratios: ",sum(pca_model.explained_variance_ratio_))
# Out:
# Sum of variance ratios:  0.7076192959775204

# %%
x_comps = pca_model.transform(x_vecs)
x_comps.shape
# Out:
# (11314, 50)

# %%
label_map = {cat:index for index,cat in enumerate(np.unique(y))}
y_prep = np.asarray([label_map[l] for l in y])

label_map
# Out:
# {'0': 0,
#  '1': 1,
#  '10': 2,
#  '11': 3,
#  '12': 4,
#  '13': 5,
#  '14': 6,
#  '15': 7,
#  '16': 8,
#  '17': 9,
#  '18': 10,
#  '19': 11,
#  '2': 12,
#  '3': 13,
#  '4': 14,
#  '5': 15,
#  '6': 16,
#  '7': 17,
#  '8': 18,
#  '9': 19,
#  'None': 20}

# %%
y
# Out:
# array(['6', '9', '9', ..., '9', '13', '9'], dtype=object)

# %%
x_train,x_test,y_train,y_test = train_test_split(x_comps,y,test_size=0.2,random_state=42)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (9051, 50)
# (2263, 50)
# (9051,)
# (2263,)

# %%
start = time.time() 

svm_classifier = SVC(kernel="linear", verbose=True)
svm_classifier.fit(x_train,y_train)

end = time.time()
process = round(end-start,2)
print("Support Vector Machine Classifier has fitted, this process took {} seconds".format(process))
# Out:
# [LibSVM]...........................................................................................................................................................................................................................................................................................................................................................................................................................*..............................................................................................................................................................................................................................................................................*.................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*........................................................................................................................................................................................................................................................*...............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*
# optimization finished, #iter = 2928366
# obj = -438.220531, rho = -1.588185
# nSV = 468, nBSV = 415
# ...............................................................................................................................................................................................................................................*............................................................................................................................................................................................*..............................................................................................................................................................................................*..*
# optimization finished, #iter = 618181
# obj = -233.058914, rho = -1.858616
# nSV = 255, nBSV = 203
# ...........................................................................................................................................................................................................................................................................................................................................................................................................*.......................................................................................................................................*.........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*.....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*..............................................................................................................................................................................................................................................*.........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*.*
# optimization finished, #iter = 2980486
# obj = -451.026390, rho = -1.589218
# nSV = 478, nBSV = 422
# ...............................................................................................................................................................................................................................................................................................................................................................................................*.................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*...............................................................................................................................................................................................................................*...............................................................................................................................................................................................................................................................................................................................*...........................................................................................................*
# optimization finished, #iter = 1912202
# obj = -230.637331, rho = -2.345757
# nSV = 260, nBSV = 204
# ..................................................
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 50861
# obj = -590.001984, rho = -1.000010
# nSV = 1756, nBSV = 385
# ............................................................................................................................................................................................................................................................*.........................................................................................................................................................................................................................................................................................................................................................................................................................................................................*..............................................................................................................................................................................................................................................................................*.................................................................................................................................................................................................................*.............................................................*...................................................................................................*............................................*.*
# optimization finished, #iter = 1391100
# obj = -348.724207, rho = -2.249833
# nSV = 377, nBSV = 322
# ..........................................................................................................................................................................................................*.................................................................................................................................................*..................................................................................................................................................................................................................................................................................................................................................................................................*...................................................................................................................................................................................................................................................................................................................................................*............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*
# optimization finished, #iter = 1803185
# obj = -296.691477, rho = -1.856666
# nSV = 323, nBSV = 271
# ..........................................................................................................................................................................................................................................................................................................................................................................................*..............................................................................................................................................................................................................................................................................................................*.....................................................................................................................................................................................................................................................................................*......................................................................................................................................................................................................................................................................................................................................................................................*........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*...*
# optimization finished, #iter = 1980339
# obj = -396.439334, rho = -1.751134
# nSV = 432, nBSV = 374
# .............................................
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 45516
# obj = -518.001511, rho = -1.000016
# nSV = 1483, nBSV = 328
# .......................................................................................................................................................*..............................................................................................................................*.........................................................................................................................................................................................*.........*
# optimization finished, #iter = 470320
# obj = -145.363596, rho = -3.523243
# nSV = 179, nBSV = 123
# ...........................................................................................................................................................................................................................................................................................................................................................................................................................................*...................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*.............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*......................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*
# optimization finished, #iter = 2559607
# obj = -512.796942, rho = -1.769919
# nSV = 546, nBSV = 487
# .....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*.........................................................................................................................................................................................................................................................................................................................................................................*.......................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*.........................................................................................................................................................................................................................................................................................................................................................................................*...........................................................................................................................................................................................................................................................................................................................................................................................................................................................*..................................................................................................*..................*
# optimization finished, #iter = 2699070
# obj = -873.158720, rho = -1.914326
# nSV = 908, nBSV = 851
# ........................................................................................................................................................................................................................................................................................................................*..................................................................................................................................................................................................................................................................................................................................................................................................................................*................................................................................................................................*...........................................................................................................................................................................................................................................................................................................*............................................................................................*.................................................................................................*...................................................................................................................................................................................................................................................................................................................................................*..........................*
# optimization finished, #iter = 1708769
# obj = -445.922025, rho = -1.469492
# nSV = 476, nBSV = 420
# ...........................................................................................................................................................................................................................................................................................................................................................*...............................................................................................................................................................................................................................................*..........................................................................................*..............*
# optimization finished, #iter = 689601
# obj = -382.991586, rho = -1.564354
# nSV = 410, nBSV = 355
# .............................................................................................................................................................*..............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*...........................................................................................................................................................................................................................................................................................................................................*..*
# optimization finished, #iter = 1078725
# obj = -153.054501, rho = -2.052909
# nSV = 183, nBSV = 130
# ...................................................*
# optimization finished, #iter = 51376
# obj = -648.000032, rho = -0.999998
# nSV = 1951, nBSV = 406
# ..........................................................................................................................................................................................................................*............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*.......................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*....................................................................................................................................................................................................................................*.*
# optimization finished, #iter = 1616898
# obj = -248.629458, rho = -1.850808
# nSV = 277, nBSV = 221
# ....................................*
# optimization finished, #iter = 36727
# obj = -450.000403, rho = -1.000057
# nSV = 1747, nBSV = 254
# .........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*.....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*...................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*.............................................................................................................................................................................................................................................................................*.................................................*....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*.............................................................................................................................................................................................................................................................................................................................................................................................*......................................................................................................................................................................................................... ...
# optimization finished, #iter = 4105736
# obj = -1852.494372, rho = -0.380175
# nSV = 1879, nBSV = 1825
# .*.*
# optimization finished, #iter = 2997
# obj = -6.703337, rho = -11.953031
# nSV = 43, nBSV = 4
# ..........................................................................................................................................................................................................................................................................................................................................................................................................................................*.......................................................................................................................................................*.............................................................................................................................................................................................................................................................................................................................................................................................................................................................*...................................................................................................................................................................................................................................................................*
# optimization finished, #iter = 617388
# obj = -229.678757, rho = -0.960284
# nSV = 254, nBSV = 203
# .....................................................................................................................................................................................................................................................................................................................................................................................................*.............................................................................................................................................................................................................................................................................................................................*............................................................................................................................................................................................................................................................................................................................................................................................................................................................*................................................................................................................................................................................................................................................................................................................................................................................................*..............................................................................................................................................................................................................................................................................*.................................*............................................................................................................................................................................................................................................................................................................................................................................................................*....................................................*
# optimization finished, #iter = 1419738
# obj = -451.292880, rho = 0.108132
# nSV = 481, nBSV = 427
# ........*....*
# optimization finished, #iter = 5693
# obj = -3.336540, rho = -5.155228
# nSV = 45, nBSV = 0
# ......................................................................................................................................................................................................................................................................................*.........................................................................................................................................................................*..........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*.................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*.....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*
# optimization finished, #iter = 1546037
# obj = -240.038084, rho = 0.505098
# nSV = 269, nBSV = 218
# .........................................................................................................................................................................................................................................................................*.......................................................................................*...................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*.......................................................................................................................................................................................................................*..*
# optimization finished, #iter = 860345
# obj = -185.729833, rho = -0.662903
# nSV = 207, nBSV = 156
# ..............................................................................................................................................................................................................................................................................................................................*....................................................................................................................................................................................................................................................................................................................*...................................................................................................................................................................................................................................................................................*.......................................................................................................................................................................................*...........................................................................*
# optimization finished, #iter = 611627
# obj = -286.560143, rho = -0.364509
# nSV = 314, nBSV = 263
# ..........................................................................................................................................................................................................*.............................................................................................*.....................................................................................................................................................................................................................*...................................................................................................................................................*
# optimization finished, #iter = 383586
# obj = -136.135509, rho = -1.074355
# nSV = 165, nBSV = 114
# .........................................................................................................................................................................................................................................................................................................................................................*..........................................................................................................................................................................................................................................................................................................................................................................................................................*.........................................................................................................................................................*.....................................................................................................................................................................*..............................................................................................................*...................................................................................................................................................................................................................................................................................................................*....................*
# optimization finished, #iter = 892558
# obj = -168.023938, rho = 0.115401
# nSV = 195, nBSV = 142
# ..............................*................................................................*
# optimization finished, #iter = 39320
# obj = -13.431144, rho = -6.905697
# nSV = 54, nBSV = 3
# .............................................................................................................................................................................................*........................................................................................*........................................................................................*...............................................*
# optimization finished, #iter = 257627
# obj = -154.108014, rho = -0.057110
# nSV = 181, nBSV = 130
# ............................................................................................................................................................*....................................................*...............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*.................................................................................................................................................................................*..*
# optimization finished, #iter = 1302705
# obj = -126.515825, rho = 0.006956
# nSV = 156, nBSV = 104
# .........................................................................................................................................................................................................................................................................................................................................*.....................................................................................................................................*...................................................................................................................................................*...............................................................................................................................................*................................................................................................*
# optimization finished, #iter = 487381
# obj = -276.764111, rho = 0.125097
# nSV = 297, nBSV = 246
# ...................................................................................................................................................................................................................................................................................................................*....................................................................................*.........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*..........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*.......................................................................................................................................................................................................................................................................................................................................*
# optimization finished, #iter = 1091629
# obj = -229.065502, rho = -0.446670
# nSV = 251, nBSV = 200
# ...
# optimization finished, #iter = 2354412
# obj = -383.846532, rho = 1.409228
# nSV = 410, nBSV = 359
# *
# optimization finished, #iter = 145
# obj = -1.466314, rho = -2.763086
# nSV = 22, nBSV = 1
# .......................................................................................................................................................................................................................................................................*......................................................................................................................................................................................................*..........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*..................................*...................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*
# optimization finished, #iter = 989063
# obj = -103.750691, rho = 1.856203
# nSV = 133, nBSV = 81
# ....................................................................................................................................................................................................................................................................................................................................................................................*.....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*..............................................................................................................................................................................................................................................................................................................................................................................................................................................*.................................................................................................................*.............*
# optimization finished, #iter = 404945
# obj = -140.565480, rho = 0.686201
# nSV = 167, nBSV = 115
# .............................................................................................*................................................................................................................................*....................................................*
# optimization finished, #iter = 85824
# obj = -45.238977, rho = 1.177126
# nSV = 76, nBSV = 26
# .....................
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 21657
# obj = -177.999299, rho = 1.000225
# nSV = 546, nBSV = 104
# *.*
# optimization finished, #iter = 115
# obj = -0.082169, rho = -1.044746
# nSV = 21, nBSV = 0
# ........................................................................................................................................................................................................................................................................................................................................................................................................................*..............................................................................................................................................................................................................................................................................*...................................................................................................................................*....................................................................................................................................................................................*.................................................................*.........................................................................................................................*
# optimization finished, #iter = 583933
# obj = -191.830918, rho = -1.331409
# nSV = 220, nBSV = 169
# ...............................................................................................................................................................................................................................................................................................................................................................................................................................................*.................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*...................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*........*....*
# optimization finished, #iter = 1659208
# obj = -264.497547, rho = -1.039246
# nSV = 294, nBSV = 240
# ..........................................................................................................................................................................................................................................................................................................................................................................................................................*....................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*......................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*.............................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*..............................................................................................................................................................................................................................................................................................................................................................................................*........................................................................................*
# optimization finished, #iter = 2788975
# obj = -635.737579, rho = 1.015244
# nSV = 666, nBSV = 612
# *.*
# optimization finished, #iter = 395
# obj = -0.285031, rho = -4.081843
# nSV = 25, nBSV = 0
# ..................................................................................................................................*..................................................................................................................................................................................................................................................................*..............................................................................................................................................*
# optimization finished, #iter = 211563
# obj = -83.302978, rho = 0.298249
# nSV = 108, nBSV = 56
# .........................
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 25733
# obj = -348.000488, rho = 1.000124
# nSV = 882, nBSV = 231
# *.*
# optimization finished, #iter = 297
# obj = -0.105604, rho = -1.693975
# nSV = 28, nBSV = 0
# .....................................................................................................................................................................................................................................................................................................*.....................................................................*................................................................................................................................................................................................................................*.........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................*........................................................................................................*.......................................................................................................................................................................*
# optimization finished, #iter = 1360407
# obj = -291.099864, rho = 1.714802
# nSV = 318, nBSV = 266
# .*
# optimization finished, #iter = 374
# obj = -0.206816, rho = -3.075521
# nSV = 24, nBSV = 0
# *.*
# optimization finished, #iter = 1341
# obj = -1.317755, rho = -7.919370
# nSV = 39, nBSV = 0
# Total nSV = 8357
# Support Vector Machine Classifier has fitted, this process took 88.04 seconds

# %%
svm_classifier.score(x_test,y_test)
# Out:
# 0.47989394608926206

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB,BernoulliNB

rfc = RandomForestClassifier()
rfc.fit(x_train,y_train)
print("Score of RFC",rfc.score(x_test,y_test))

logreg = LogisticRegression()
logreg.fit(x_train,y_train)
print("Score of LogReg",logreg.score(x_test,y_test))

gnb = GaussianNB()
gnb.fit(x_train,y_train)
print("Score of GaussianNB",gnb.score(x_test,y_test))

bnb = BernoulliNB()
bnb.fit(x_train,y_train)
print("Score of BernoulliNB",bnb.score(x_test,y_test))
# Out:
# Score of RFC 0.4471939902783915
# Score of LogReg 0.4768007070260716
# Score of GaussianNB 0.34290764471939905
# Score of BernoulliNB 0.41493592576226246
# /Users/timothyray/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
